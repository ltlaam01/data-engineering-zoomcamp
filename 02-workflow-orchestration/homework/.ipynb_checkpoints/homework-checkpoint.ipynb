# %% [markdown]
# ## 1. Within the execution for Yellow Taxi data for the year 2020 and month 12: what is the uncompressed file size (i.e. the output file yellow_tripdata_2020-12.csv of the extract task)?
# - 128.3 MB
# - 134.5 MB
# - 364.7 MB
# - 692.6 MB

# %%
! wget -qO- https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2020-12.csv.gz | gunzip > /root/ltlaam01/data/yellow_tripdata_2020-12.csv
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory

# %%
! ls -l /root/ltlaam01/data/yellow_tripdata_2020-12.csv
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# -rw-r--r-- 1 root root 134481400 Feb  7 18:29 /root/ltlaam01/data/yellow_tripdata_2020-12.csv

# %%
print(134481400 / (1024 ** 2 ))
# Out:
# 128.25145721435547

# %% [markdown]
# => the answer is "128.3 MB"

# %% [markdown]
# ## 2. What is the rendered value of the variable file when the inputs taxi is set to green, year is set to 2020, and month is set to 04 during execution?
# - {{inputs.taxi}}_tripdata_{{inputs.year}}-{{inputs.month}}.csv
# - green_tripdata_2020-04.csv
# - green_tripdata_04_2020.csv
# - green_tripdata_2020.csv

# %% [markdown]
# flow:

# %% [raw]
# id: test_render
# namespace: homework
#
# inputs:
#   - id: taxi
#     type: SELECT
#     displayName: Select taxi type
#     values: [yellow, "green"]
#     defaults: green
#
#   - id: year
#     type: SELECT
#     displayName: Select year
#     values: ["2019", "2020"]
#     defaults: "2020"
#
#   - id: month
#     type: SELECT
#     displayName: Select month
#     values: ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"]
#     defaults: "04"
#
# variables:
#   file: "{{inputs.taxi}}_tripdata_{{inputs.year}}-{{inputs.month}}.csv"
#
# tasks:
#   - id: rendered_value
#     type: io.kestra.plugin.core.log.Log
#     message: "{{render(vars.file)}}"

# %% [markdown]
# ![image.png](attachment:63b08bba-0c09-4310-92df-5f99515b8641.png)

# %% [markdown]
# => the answer is "green_tripdata_2020-04.csv"

# %% [markdown]
# ## 3. How many rows are there for the `Yellow` Taxi data for all CSV files in the year 2020?
# - 13,537.299
# - 24,648,499
# - 18,324,219
# - 29,430,127

# %% [markdown]
# ![image.png](attachment:81548421-d980-4866-94f2-9417fb33296e.png)

# %% [markdown]
# => the answer is "24,648,499"

# %% [markdown]
# ## 4. How many rows are there for the Green Taxi data for all CSV files in the year 2020?
# - 5,327,301
# - 936,199
# - 1,734,051
# - 1,342,034

# %% [markdown]
# ![image.png](attachment:db982d64-596a-4896-b92c-91647b6adb24.png)

# %% [markdown]
# => the answer is "1,734,051"

# %% [markdown]
# ## 5. How many rows are there for the Yellow Taxi data for the March 2021 CSV file?
# - 1,428,092
# - 706,911
# - 1,925,152
# - 2,561,031

# %% [markdown]
# ![image.png](attachment:88c55d3a-76c6-4b9b-9301-3fac78bc9aa0.png)

# %% [markdown]
# => the answer is "1,925,152"

# %% [markdown]
# ## 6. How would you configure the timezone to New York in a Schedule trigger?
# - Add a timezone property set to EST in the Schedule trigger configuration
# - Add a timezone property set to America/New_York in the Schedule trigger configuration
# - Add a timezone property set to UTC-5 in the Schedule trigger configuration
# - Add a location property set to New_York in the Schedule trigger configuration

# %% [markdown]
# following the doc https://kestra.io/docs/workflow-components/triggers/schedule-trigger
#
# ![image.png](attachment:f968bfc4-b7b2-4844-942f-5a1bada4cbde.png)
#
# the "timezone" attribute follows cron-tab config.

# %% [markdown]
# => the answer is "Add a timezone property set to America/New_York in the Schedule trigger configuration"
